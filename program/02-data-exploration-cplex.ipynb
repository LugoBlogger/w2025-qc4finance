# %% [markdown]
# Logs
# - [2025/08/06]
#   First version of this notebook to explore `.lp` files in `/data/1/*`
#
# - [2025/08/07]
#   We try to use the smallest number of constraint to understand the
#   problem and how to get the data from the spreadsheet

# %% [markdown]
# **References**
#
# - [DOcplex documentation](https://ibmdecisionoptimization.github.io/docplex-doc/)

# %% [markdown]
# **Required packges**
# - `docplex==2.30.251`
# - `cplex==22.1.2.0`

# %%
import docplex
import docplex.mp.model as cpx
import pandas as pd
import xml.etree.ElementTree as ET
import re
import numpy as np

from docplex.mp.model_reader import ModelReader
from docplex.mp.solution import SolveSolution

# %%
docplex.__version__
# Out:
# '2.30.251'

# %%
# lp_file_path = "./data/1/31bonds/docplex.lp"
# lp_file_path = "./data/1/31bonds/docplex-bin-avgonly.lp"
# lp_file_path = "./data/1/31bonds/docplex-bin-minmaxavg.lp"
lp_file_path = "./data/1/31bonds/docplex-bin-avgonly-nocplexvars.lp"
# lp_file_path = "./data/1/full/docplex-orig.lp"
model = ModelReader.read(lp_file_path)

# %%
model_info = {
  "model_name": model.name,
  "problem_type": "Minimization" if model.is_minimized() else "Maximization",
  "num_variables": model.number_of_variables,
  "num_constraints": model.number_of_constraints,
  "num_binary_vars": len([v for v in model.iter_variables() if v.is_binary()]),
  "num_integer_vars": len([v for v in model.iter_variables() if v.is_integer()]),
  "num_continuous_vars": model.number_of_semicontinuous_variables,
}


for k, v in model_info.items():
  print(f"{k:>20s}", v)
# Out:
#           model_name docplex-bin-avgonly-nocplexvars
#         problem_type Minimization
#        num_variables 31
#      num_constraints 15
#      num_binary_vars 31
#     num_integer_vars 0
#  num_continuous_vars 0

# %%
dir(model)
# Out:
# ['DEFAULT_OBJECTIVE_FMT',
#  'DEFAULT_VAR_VALUE_QUOTED_SOLUTION_FMT',
#  'DEFAULT_VAR_VALUE_UNQUOTED_SOLUTION_FMT',
#  '_Model__allpwlfuncs',
#  '_Model__engine',
#  '_Model__notify_new_model_object',
#  '__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__enter__',
#  '__eq__',
#  '__exit__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__iadd__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_add_batch_logical_cts',
#  '_add_constraint_internal',
#  '_add_indicator',
#  '_add_progress_listener',
#  '_add_pwl_constraint_internal',
#  '_add_pwl_expr',
#  '_add_qprogress_listener',
#  '_add_sos',
#  '_add_var_container',
#  '_aggregator',
#  '_all_containers',
#  '_allkpis',
#  '_apply_parameters_to_engine',
#  '_benders_annotations',
#  '_binary_vartype',
#  '_cached_sos_weights',
#  '_can_solve',
#  '_change_var_types_internal',
#  '_check_basis',
#  '_check_has_multi_objective',
#  '_check_has_solution',
#  '_check_logical_constraint_support',
#  '_check_mip_for_mipstarts',
#  '_check_multi_objective_support',
#  '_check_name',
#  '_check_new_ct_index',
#  '_check_problem_type',
#  '_check_scope_indices',
#  '_check_solved_as_mip',
#  '_check_trivial_constraints',
#  '_checker',
#  '_checker_key',
#  '_clean_before_solve',
#  '_clear_cached_discrete_var',
#  '_clear_internal',
#  '_clear_multi_objective',
#  '_clear_objective_expr',
#  '_clear_qprogress_listeners',
#  '_clear_scopes',
#  '_clear_solution',
#  '_compile_multiobj_expr_list',
#  '_compute_changed_var_bounds',
#  '_connect_progress_listeners',
#  '_constraint_priority_dict',
#  '_container_map',
#  '_contains_discrete_artefacts',
#  '_continuous_vartype',
#  '_count_constraints_with_type',
#  '_count_variables_w_code',
#  '_create_engine_constraint',
#  '_create_engine_sos',
#  '_cts_by_name',
#  '_ctstatus_counter',
#  '_default_effort_level',
#  '_disambiguate_varname',
#  '_disconnect_progress_listeners',
#  '_dual_value1',
#  '_dual_values',
#  '_engine_factory',
#  '_ensure_benders_annotations',
#  '_ensure_cts_name_dir',
#  '_ensure_var_to_container_map',
#  '_environment',
#  '_error_handler',
#  '_export',
#  '_export_as_cplex_string',
#  '_export_from_cplex',
#  '_export_to_lp_stream',
#  '_export_to_path',
#  '_export_to_stream',
#  '_extend_constraint_section',
#  '_find_matching_objs',
#  '_fire_end_solve_listeners',
#  '_fire_start_solve_listeners',
#  '_float_meta_format',
#  '_float_precision',
#  '_generate_sos',
#  '_generic_get_basis_status',
#  '_get_cached_sos_weights',
#  '_get_cplex',
#  '_get_cplex_engine',
#  '_get_cplex_problem_type',
#  '_get_kwargs',
#  '_get_number_of_var_containers',
#  '_get_obj_scope',
#  '_get_printer',
#  '_get_solution',
#  '_get_sos_by_index',
#  '_has_piecewise',
#  '_has_solution',
#  '_has_username_with_spaces',
#  '_ignore_names',
#  '_indicator_trivial_feasible_idx',
#  '_indicator_trivial_infeasible_idx',
#  '_integer_vartype',
#  '_is_binary_var',
#  '_is_continuous_var',
#  '_is_cplex_ce',
#  '_is_integer_var',
#  '_is_lazy_constraint',
#  '_is_qc',
#  '_is_qp',
#  '_is_semicontinuous_var',
#  '_is_semiinteger_var',
#  '_is_user_cut_constraint',
#  '_iter_constraint_scopes',
#  '_iter_scopes',
#  '_iter_variables_w_code',
#  '_keep_all_exprs',
#  '_keep_ordering',
#  '_last_solve_status',
#  '_lazy_constraints',
#  '_lazy_get_environment',
#  '_lfactory',
#  '_linct_scope',
#  '_linearct_basis_status',
#  '_logical_scope',
#  '_lp_line_length',
#  '_make_end_infodict',
#  '_make_environment',
#  '_make_lex_priorities',
#  '_make_new_engine_from_agent',
#  '_make_new_stats',
#  '_make_output_path',
#  '_matching_kpi',
#  '_max_str_len',
#  '_mipstarts',
#  '_multi_objective',
#  '_multi_objective_values',
#  '_name',
#  '_name_functional_vars',
#  '_name_generator',
#  '_new_ct_status_index',
#  '_new_default_objective_expr',
#  '_new_engine',
#  '_new_linear_factory',
#  '_new_lp_printer',
#  '_new_quadratic_factory',
#  '_new_xconstraint',
#  '_notify_solve_hit_limit',
#  '_notify_trivial_constraint',
#  '_nth_multi_objective',
#  '_num_printer',
#  '_numpy_print_str',
#  '_objective_coef',
#  '_objective_expr',
#  '_objective_sense',
#  '_objective_value',
#  '_origin_map',
#  '_parse_agent',
#  '_parse_kwargs',
#  '_parse_vartype',
#  '_piecewise',
#  '_post_constraint',
#  '_post_quadratic_constraint',
#  '_prepare_constraint',
#  '_print_full_obj',
#  '_problem_type_from_cplex',
#  '_progress_listeners',
#  '_provenance',
#  '_pwl_scope',
#  '_qfactory',
#  '_qprogress_listeners',
#  '_quad_count',
#  '_quadct_scope',
#  '_quality_metrics',
#  '_read_cplex_file',
#  '_readable_str_len',
#  '_reduced_cost1',
#  '_reduced_costs',
#  '_register_block_cts',
#  '_register_block_vars',
#  '_register_ct_name',
#  '_register_implicit_equivalence_ct',
#  '_register_one_constraint',
#  '_register_one_pwl_constraint',
#  '_register_one_var',
#  '_register_sos',
#  '_remove_constraint_internal',
#  '_remove_constraints_internal',
#  '_report_lexicographic_goals',
#  '_reported_objective_value',
#  '_resolve_ct',
#  '_resolve_path',
#  '_resolve_pwls',
#  '_resolve_sense',
#  '_resync',
#  '_round_element_value_if_necessary',
#  '_round_function',
#  '_round_solution',
#  '_saved_numpy_options',
#  '_scope_dict',
#  '_semicontinuous_vartype',
#  '_semiinteger_vartype',
#  '_set_engine',
#  '_set_engine_multi_objective_exprs',
#  '_set_lex_multi_objective',
#  '_set_multi_objective_exprs',
#  '_set_multi_objective_internal',
#  '_set_new_engine_from_agent',
#  '_set_solution',
#  '_set_solver_agent',
#  '_set_var_lb',
#  '_set_var_type',
#  '_set_var_ub',
#  '_slack_value1',
#  '_slack_values',
#  '_solution',
#  '_solve_details',
#  '_solve_local',
#  '_solved_as_lp',
#  '_solved_as_mip',
#  '_sos_scope',
#  '_static_terminate_engine',
#  '_supports_logical_constraints',
#  '_supports_multi_objective',
#  '_sync_params',
#  '_synced_params',
#  '_terminate_engine',
#  '_typecheck_as_denominator',
#  '_typecheck_num',
#  '_typecheck_optional_num_seq',
#  '_typecheck_var',
#  '_unknown_status',
#  '_update_var_bounds_from_type',
#  '_use_space_str',
#  '_user_cuts',
#  '_var',
#  '_var_basis_status',
#  '_var_basis_status1',
#  '_var_by_index',
#  '_var_dict',
#  '_var_list',
#  '_var_multidict',
#  '_var_scope',
#  '_vars_by_name',
#  '_vartypes',
#  '_write_cplex_file',
#  'abs',
#  'add',
#  'add_',
#  'add_constraint',
#  'add_constraint_',
#  'add_constraints',
#  'add_constraints_',
#  'add_equivalence',
#  'add_equivalence_constraints',
#  'add_equivalence_constraints_',
#  'add_equivalences',
#  'add_if_then',
#  'add_indicator',
#  'add_indicator_constraints',
#  'add_indicator_constraints_',
#  'add_indicators',
#  'add_kpi',
#  'add_lazy_constraint',
#  'add_lazy_constraints',
#  'add_mip_start',
#  'add_piecewise_constraint',
#  'add_progress_listener',
#  'add_quadratic_constraints',
#  'add_range',
#  'add_ranges',
#  'add_sos',
#  'add_sos1',
#  'add_sos2',
#  'add_user_cut_constraint',
#  'add_user_cut_constraints',
#  'apply_one_parameter',
#  'apply_parameters',
#  'binary_var',
#  'binary_var_cube',
#  'binary_var_dict',
#  'binary_var_list',
#  'binary_var_matrix',
#  'binary_vartype',
#  'blended_objective_values',
#  'build_multiobj_paramsets',
#  'cannot_be_used_as_denominator_error',
#  'change_var_lower_bounds',
#  'change_var_types',
#  'change_var_upper_bounds',
#  'clean_before_solve',
#  'clear',
#  'clear_benders_annotations',
#  'clear_constraints',
#  'clear_engine_before_solve',
#  'clear_kpis',
#  'clear_lazy_constraints',
#  'clear_mip_starts',
#  'clear_multi_objective',
#  'clear_progress_listeners',
#  'clear_sos',
#  'clear_user_cut_constraints',
#  'clone',
#  'context',
#  'continuous_var',
#  'continuous_var_cube',
#  'continuous_var_dict',
#  'continuous_var_list',
#  'continuous_var_matrix',
#  'continuous_vartype',
#  'copy',
#  'cplex',
#  'cplex_matrix_stats',
#  'create_parameter_sets',
#  'default_objective_sense',
#  'dot',
#  'dotf',
#  'dual_values',
#  'dump_as_lp',
#  'dump_as_sav',
#  'enable_cts_by_name_dict',
#  'end',
#  'environment',
#  'eq_constraint',
#  'equivalence_constraint',
#  'error',
#  'error_handler',
#  'export',
#  'export_annotations',
#  'export_as_lp',
#  'export_as_lp_string',
#  'export_as_mps',
#  'export_as_mps_string',
#  'export_as_sav',
#  'export_as_sav_string',
#  'export_as_savgz',
#  'export_basis',
#  'export_parameters_as_ops',
#  'export_parameters_as_prm',
#  'export_priority_order_file',
#  'export_to_stream',
#  'fatal',
#  'fatal_ce_limits',
#  'find_matching_linear_constraints',
#  'find_matching_quadratic_constraints',
#  'find_matching_vars',
#  'find_re_matching_vars',
#  'float_precision',
#  'ge_constraint',
#  'generate_user_linear_constraints',
#  'generate_user_variables',
#  'get_annotation_stats',
#  'get_annotations_by_scope',
#  'get_benders_annotation',
#  'get_constraint_by_index',
#  'get_constraint_by_name',
#  'get_constraint_priority',
#  'get_cplex',
#  'get_cuts',
#  'get_engine',
#  'get_engine_parameter_value',
#  'get_hidden_parameter',
#  'get_logical_constraint_by_index',
#  'get_num_cuts',
#  'get_obj_origin',
#  'get_objective_expr',
#  'get_parameter_from_id',
#  'get_pwl_constraint_by_index',
#  'get_quadratic_constraint_by_index',
#  'get_solve_details',
#  'get_solve_status',
#  'get_statistics',
#  'get_time_limit',
#  'get_var_by_index',
#  'get_var_by_name',
#  'get_var_container',
#  'has_basis',
#  'has_benders_annotations',
#  'has_cplex',
#  'has_cts_by_name_dict',
#  'has_multi_objective',
#  'has_objective',
#  'has_quadratic_constraint',
#  'if_then',
#  'ignore_names',
#  'import_solution',
#  'indicator_constraint',
#  'infinity',
#  'info',
#  'init_numpy',
#  'integer_var',
#  'integer_var_cube',
#  'integer_var_dict',
#  'integer_var_list',
#  'integer_var_matrix',
#  'integer_vartype',
#  'is_cplex_ce',
#  'is_docplex_debug',
#  'is_logged',
#  'is_maximized',
#  'is_minimized',
#  'is_optimized',
#  'is_quadratic',
#  'iter_benders_annotations',
#  'iter_binary_constraints',
#  'iter_binary_vars',
#  'iter_constraints',
#  'iter_continuous_vars',
#  'iter_equivalence_constraints',
#  'iter_indicator_constraints',
#  'iter_integer_vars',
#  'iter_kpis',
#  'iter_lazy_constraints',
#  'iter_linear_constraints',
#  'iter_logical_constraints',
#  'iter_mip_starts',
#  'iter_multi_objective_exprs',
#  'iter_multi_objective_tuples',
#  'iter_progress_listeners',
#  'iter_pwl_constraints',
#  'iter_pwl_functions',
#  'iter_quadratic_constraints',
#  'iter_range_constraints',
#  'iter_semicontinuous_vars',
#  'iter_semiinteger_vars',
#  'iter_sos',
#  'iter_sos1',
#  'iter_sos2',
#  'iter_user_cut_constraints',
#  'iter_var_containers',
#  'iter_variables',
#  'iter_vartypes',
#  'job_solve_status',
#  'keep_ordering',
#  'kpi_by_name',
#  'kpi_value_by_name',
#  'kpis_as_dict',
#  'le_constraint',
#  'lfactory',
#  'linear_constraint',
#  'linear_constraint_basis_statuses',
#  'linear_expr',
#  'log_output',
#  'logger',
#  'logical_and',
#  'logical_not',
#  'logical_or',
#  'lp_line_length',
#  'lp_string',
#  'max',
#  'maximize',
#  'maximize_static_lex',
#  'min',
#  'minimize',
#  'minimize_static_lex',
#  'mip_starts',
#  'multi_objective_values',
#  'name',
#  'new_solution',
#  'not_equal_constraint',
#  'notify_expr_modified',
#  'notify_expr_replaced',
#  'notify_solve_failed',
#  'notify_solve_relaxed',
#  'notify_start_solve',
#  'number_of_binary_variables',
#  'number_of_constraints',
#  'number_of_continuous_variables',
#  'number_of_equivalence_constraints',
#  'number_of_errors',
#  'number_of_generated_variables',
#  'number_of_indicator_constraints',
#  'number_of_integer_variables',
#  'number_of_kpis',
#  'number_of_lazy_constraints',
#  'number_of_linear_constraints',
#  'number_of_mip_starts',
#  'number_of_multi_objective_exprs',
#  'number_of_nonzeros',
#  'number_of_progress_listeners',
#  'number_of_pwl_constraints',
#  'number_of_quadratic_constraints',
#  'number_of_range_constraints',
#  'number_of_semicontinuous_variables',
#  'number_of_semiinteger_variables',
#  'number_of_sos',
#  'number_of_sos1',
#  'number_of_sos2',
#  'number_of_user_constraints',
#  'number_of_user_cut_constraints',
#  'number_of_user_variables',
#  'number_of_variables',
#  'number_of_warnings',
#  'objective_coef',
#  'objective_expr',
#  'objective_sense',
#  'objective_value',
#  'origin_key',
#  'output_level',
#  'parameters',
#  'piecewise',
#  'piecewise_as_slopes',
#  'populate',
#  'populate_solution_pool',
#  'pprint',
#  'pprint_as_string',
#  'prepare_actual_context',
#  'prettyprint',
#  'print_information',
#  'print_solution',
#  'problem_type',
#  'provenance',
#  'quad_expr',
#  'quadratic_dual_slacks',
#  'quality_metrics',
#  'range_constraint',
#  'read_basis_file',
#  'read_mip_starts',
#  'read_priority_order_file',
#  'readable_str_len',
#  'reduced_costs',
#  'register_callback',
#  'remove',
#  'remove_benders_annotation',
#  'remove_constraint',
#  'remove_constraints',
#  'remove_kpi',
#  'remove_objective',
#  'remove_progress_listener',
#  'report',
#  'report_kpis',
#  'restore_numpy',
#  'restore_solution',
#  'resync_engine',
#  'round_solution',
#  'scal_prod',
#  'scal_prod_f',
#  'scal_prod_vars_all_different',
#  'semicontinuous_var',
#  'semicontinuous_var_dict',
#  'semicontinuous_var_list',
#  'semicontinuous_var_matrix',
#  'semicontinuous_vartype',
#  'semiinteger_var',
#  'semiinteger_var_dict',
#  'semiinteger_var_list',
#  'semiinteger_var_matrix',
#  'semiinteger_vartype',
#  'set_benders_annotation',
#  'set_checker',
#  'set_constraint_priority',
#  'set_hidden_parameter',
#  'set_lex_multi_objective',
#  'set_linear_constraint_name',
#  'set_log_output',
#  'set_log_output_as_stream',
#  'set_lp_start_basis',
#  'set_multi_objective',
#  'set_multi_objective_abstols',
#  'set_multi_objective_exprs',
#  'set_multi_objective_reltols',
#  'set_obj_origin',
#  'set_objective',
#  'set_objective_expr',
#  'set_objective_sense',
#  'set_quiet',
#  'set_time_limit',
#  'set_var_container',
#  'set_var_lb',
#  'set_var_name',
#  'set_var_ub',
#  'slack_values',
#  'solution',
#  'solve',
#  'solve_details',
#  'solve_status',
#  'solve_with_goals',
#  'solved_stopped_by_limit',
#  'solver_agent',
#  'solves_with',
#  'statistics',
#  'str_max_len',
#  'str_space',
#  'str_use_space',
#  'sum',
#  'sum_squares',
#  'sum_vars',
#  'sum_vars_all_different',
#  'sums',
#  'sumsq',
#  'supports_logical_constraints',
#  'supports_multi_objective',
#  'sync_cplex_engine',
#  'time_limit',
#  'time_limit_parameter',
#  'to_string',
#  'trace',
#  'unsupported_power_error',
#  'unsupported_relational_operator_error',
#  'var',
#  'var_basis_statuses',
#  'var_dict',
#  'var_hypercube',
#  'var_list',
#  'var_matrix',
#  'vector_compare',
#  'vector_compare_eq',
#  'vector_compare_ge',
#  'vector_compare_le',
#  'warning']

# %%
binary_vars = model.binary_var()
binary_vars
# Out:
# docplex.mp.Var(type=B)

# %% [markdown]
# ### Objective function

# %%
dir(model)
# Out:
# ['DEFAULT_OBJECTIVE_FMT',
#  'DEFAULT_VAR_VALUE_QUOTED_SOLUTION_FMT',
#  'DEFAULT_VAR_VALUE_UNQUOTED_SOLUTION_FMT',
#  '_Model__allpwlfuncs',
#  '_Model__engine',
#  '_Model__notify_new_model_object',
#  '__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__enter__',
#  '__eq__',
#  '__exit__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__iadd__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_add_batch_logical_cts',
#  '_add_constraint_internal',
#  '_add_indicator',
#  '_add_progress_listener',
#  '_add_pwl_constraint_internal',
#  '_add_pwl_expr',
#  '_add_qprogress_listener',
#  '_add_sos',
#  '_add_var_container',
#  '_aggregator',
#  '_all_containers',
#  '_allkpis',
#  '_apply_parameters_to_engine',
#  '_benders_annotations',
#  '_binary_vartype',
#  '_cached_sos_weights',
#  '_can_solve',
#  '_change_var_types_internal',
#  '_check_basis',
#  '_check_has_multi_objective',
#  '_check_has_solution',
#  '_check_logical_constraint_support',
#  '_check_mip_for_mipstarts',
#  '_check_multi_objective_support',
#  '_check_name',
#  '_check_new_ct_index',
#  '_check_problem_type',
#  '_check_scope_indices',
#  '_check_solved_as_mip',
#  '_check_trivial_constraints',
#  '_checker',
#  '_checker_key',
#  '_clean_before_solve',
#  '_clear_cached_discrete_var',
#  '_clear_internal',
#  '_clear_multi_objective',
#  '_clear_objective_expr',
#  '_clear_qprogress_listeners',
#  '_clear_scopes',
#  '_clear_solution',
#  '_compile_multiobj_expr_list',
#  '_compute_changed_var_bounds',
#  '_connect_progress_listeners',
#  '_constraint_priority_dict',
#  '_container_map',
#  '_contains_discrete_artefacts',
#  '_continuous_vartype',
#  '_count_constraints_with_type',
#  '_count_variables_w_code',
#  '_create_engine_constraint',
#  '_create_engine_sos',
#  '_cts_by_name',
#  '_ctstatus_counter',
#  '_default_effort_level',
#  '_disambiguate_varname',
#  '_disconnect_progress_listeners',
#  '_dual_value1',
#  '_dual_values',
#  '_engine_factory',
#  '_ensure_benders_annotations',
#  '_ensure_cts_name_dir',
#  '_ensure_var_to_container_map',
#  '_environment',
#  '_error_handler',
#  '_export',
#  '_export_as_cplex_string',
#  '_export_from_cplex',
#  '_export_to_lp_stream',
#  '_export_to_path',
#  '_export_to_stream',
#  '_extend_constraint_section',
#  '_find_matching_objs',
#  '_fire_end_solve_listeners',
#  '_fire_start_solve_listeners',
#  '_float_meta_format',
#  '_float_precision',
#  '_generate_sos',
#  '_generic_get_basis_status',
#  '_get_cached_sos_weights',
#  '_get_cplex',
#  '_get_cplex_engine',
#  '_get_cplex_problem_type',
#  '_get_kwargs',
#  '_get_number_of_var_containers',
#  '_get_obj_scope',
#  '_get_printer',
#  '_get_solution',
#  '_get_sos_by_index',
#  '_has_piecewise',
#  '_has_solution',
#  '_has_username_with_spaces',
#  '_ignore_names',
#  '_indicator_trivial_feasible_idx',
#  '_indicator_trivial_infeasible_idx',
#  '_integer_vartype',
#  '_is_binary_var',
#  '_is_continuous_var',
#  '_is_cplex_ce',
#  '_is_integer_var',
#  '_is_lazy_constraint',
#  '_is_qc',
#  '_is_qp',
#  '_is_semicontinuous_var',
#  '_is_semiinteger_var',
#  '_is_user_cut_constraint',
#  '_iter_constraint_scopes',
#  '_iter_scopes',
#  '_iter_variables_w_code',
#  '_keep_all_exprs',
#  '_keep_ordering',
#  '_last_solve_status',
#  '_lazy_constraints',
#  '_lazy_get_environment',
#  '_lfactory',
#  '_linct_scope',
#  '_linearct_basis_status',
#  '_logical_scope',
#  '_lp_line_length',
#  '_make_end_infodict',
#  '_make_environment',
#  '_make_lex_priorities',
#  '_make_new_engine_from_agent',
#  '_make_new_stats',
#  '_make_output_path',
#  '_matching_kpi',
#  '_max_str_len',
#  '_mipstarts',
#  '_multi_objective',
#  '_multi_objective_values',
#  '_name',
#  '_name_functional_vars',
#  '_name_generator',
#  '_new_ct_status_index',
#  '_new_default_objective_expr',
#  '_new_engine',
#  '_new_linear_factory',
#  '_new_lp_printer',
#  '_new_quadratic_factory',
#  '_new_xconstraint',
#  '_notify_solve_hit_limit',
#  '_notify_trivial_constraint',
#  '_nth_multi_objective',
#  '_num_printer',
#  '_numpy_print_str',
#  '_objective_coef',
#  '_objective_expr',
#  '_objective_sense',
#  '_objective_value',
#  '_origin_map',
#  '_parse_agent',
#  '_parse_kwargs',
#  '_parse_vartype',
#  '_piecewise',
#  '_post_constraint',
#  '_post_quadratic_constraint',
#  '_prepare_constraint',
#  '_print_full_obj',
#  '_problem_type_from_cplex',
#  '_progress_listeners',
#  '_provenance',
#  '_pwl_scope',
#  '_qfactory',
#  '_qprogress_listeners',
#  '_quad_count',
#  '_quadct_scope',
#  '_quality_metrics',
#  '_read_cplex_file',
#  '_readable_str_len',
#  '_reduced_cost1',
#  '_reduced_costs',
#  '_register_block_cts',
#  '_register_block_vars',
#  '_register_ct_name',
#  '_register_implicit_equivalence_ct',
#  '_register_one_constraint',
#  '_register_one_pwl_constraint',
#  '_register_one_var',
#  '_register_sos',
#  '_remove_constraint_internal',
#  '_remove_constraints_internal',
#  '_report_lexicographic_goals',
#  '_reported_objective_value',
#  '_resolve_ct',
#  '_resolve_path',
#  '_resolve_pwls',
#  '_resolve_sense',
#  '_resync',
#  '_round_element_value_if_necessary',
#  '_round_function',
#  '_round_solution',
#  '_saved_numpy_options',
#  '_scope_dict',
#  '_semicontinuous_vartype',
#  '_semiinteger_vartype',
#  '_set_engine',
#  '_set_engine_multi_objective_exprs',
#  '_set_lex_multi_objective',
#  '_set_multi_objective_exprs',
#  '_set_multi_objective_internal',
#  '_set_new_engine_from_agent',
#  '_set_solution',
#  '_set_solver_agent',
#  '_set_var_lb',
#  '_set_var_type',
#  '_set_var_ub',
#  '_slack_value1',
#  '_slack_values',
#  '_solution',
#  '_solve_details',
#  '_solve_local',
#  '_solved_as_lp',
#  '_solved_as_mip',
#  '_sos_scope',
#  '_static_terminate_engine',
#  '_supports_logical_constraints',
#  '_supports_multi_objective',
#  '_sync_params',
#  '_synced_params',
#  '_terminate_engine',
#  '_typecheck_as_denominator',
#  '_typecheck_num',
#  '_typecheck_optional_num_seq',
#  '_typecheck_var',
#  '_unknown_status',
#  '_update_var_bounds_from_type',
#  '_use_space_str',
#  '_user_cuts',
#  '_var',
#  '_var_basis_status',
#  '_var_basis_status1',
#  '_var_by_index',
#  '_var_dict',
#  '_var_list',
#  '_var_multidict',
#  '_var_scope',
#  '_vars_by_name',
#  '_vartypes',
#  '_write_cplex_file',
#  'abs',
#  'add',
#  'add_',
#  'add_constraint',
#  'add_constraint_',
#  'add_constraints',
#  'add_constraints_',
#  'add_equivalence',
#  'add_equivalence_constraints',
#  'add_equivalence_constraints_',
#  'add_equivalences',
#  'add_if_then',
#  'add_indicator',
#  'add_indicator_constraints',
#  'add_indicator_constraints_',
#  'add_indicators',
#  'add_kpi',
#  'add_lazy_constraint',
#  'add_lazy_constraints',
#  'add_mip_start',
#  'add_piecewise_constraint',
#  'add_progress_listener',
#  'add_quadratic_constraints',
#  'add_range',
#  'add_ranges',
#  'add_sos',
#  'add_sos1',
#  'add_sos2',
#  'add_user_cut_constraint',
#  'add_user_cut_constraints',
#  'apply_one_parameter',
#  'apply_parameters',
#  'binary_var',
#  'binary_var_cube',
#  'binary_var_dict',
#  'binary_var_list',
#  'binary_var_matrix',
#  'binary_vartype',
#  'blended_objective_values',
#  'build_multiobj_paramsets',
#  'cannot_be_used_as_denominator_error',
#  'change_var_lower_bounds',
#  'change_var_types',
#  'change_var_upper_bounds',
#  'clean_before_solve',
#  'clear',
#  'clear_benders_annotations',
#  'clear_constraints',
#  'clear_engine_before_solve',
#  'clear_kpis',
#  'clear_lazy_constraints',
#  'clear_mip_starts',
#  'clear_multi_objective',
#  'clear_progress_listeners',
#  'clear_sos',
#  'clear_user_cut_constraints',
#  'clone',
#  'context',
#  'continuous_var',
#  'continuous_var_cube',
#  'continuous_var_dict',
#  'continuous_var_list',
#  'continuous_var_matrix',
#  'continuous_vartype',
#  'copy',
#  'cplex',
#  'cplex_matrix_stats',
#  'create_parameter_sets',
#  'default_objective_sense',
#  'dot',
#  'dotf',
#  'dual_values',
#  'dump_as_lp',
#  'dump_as_sav',
#  'enable_cts_by_name_dict',
#  'end',
#  'environment',
#  'eq_constraint',
#  'equivalence_constraint',
#  'error',
#  'error_handler',
#  'export',
#  'export_annotations',
#  'export_as_lp',
#  'export_as_lp_string',
#  'export_as_mps',
#  'export_as_mps_string',
#  'export_as_sav',
#  'export_as_sav_string',
#  'export_as_savgz',
#  'export_basis',
#  'export_parameters_as_ops',
#  'export_parameters_as_prm',
#  'export_priority_order_file',
#  'export_to_stream',
#  'fatal',
#  'fatal_ce_limits',
#  'find_matching_linear_constraints',
#  'find_matching_quadratic_constraints',
#  'find_matching_vars',
#  'find_re_matching_vars',
#  'float_precision',
#  'ge_constraint',
#  'generate_user_linear_constraints',
#  'generate_user_variables',
#  'get_annotation_stats',
#  'get_annotations_by_scope',
#  'get_benders_annotation',
#  'get_constraint_by_index',
#  'get_constraint_by_name',
#  'get_constraint_priority',
#  'get_cplex',
#  'get_cuts',
#  'get_engine',
#  'get_engine_parameter_value',
#  'get_hidden_parameter',
#  'get_logical_constraint_by_index',
#  'get_num_cuts',
#  'get_obj_origin',
#  'get_objective_expr',
#  'get_parameter_from_id',
#  'get_pwl_constraint_by_index',
#  'get_quadratic_constraint_by_index',
#  'get_solve_details',
#  'get_solve_status',
#  'get_statistics',
#  'get_time_limit',
#  'get_var_by_index',
#  'get_var_by_name',
#  'get_var_container',
#  'has_basis',
#  'has_benders_annotations',
#  'has_cplex',
#  'has_cts_by_name_dict',
#  'has_multi_objective',
#  'has_objective',
#  'has_quadratic_constraint',
#  'if_then',
#  'ignore_names',
#  'import_solution',
#  'indicator_constraint',
#  'infinity',
#  'info',
#  'init_numpy',
#  'integer_var',
#  'integer_var_cube',
#  'integer_var_dict',
#  'integer_var_list',
#  'integer_var_matrix',
#  'integer_vartype',
#  'is_cplex_ce',
#  'is_docplex_debug',
#  'is_logged',
#  'is_maximized',
#  'is_minimized',
#  'is_optimized',
#  'is_quadratic',
#  'iter_benders_annotations',
#  'iter_binary_constraints',
#  'iter_binary_vars',
#  'iter_constraints',
#  'iter_continuous_vars',
#  'iter_equivalence_constraints',
#  'iter_indicator_constraints',
#  'iter_integer_vars',
#  'iter_kpis',
#  'iter_lazy_constraints',
#  'iter_linear_constraints',
#  'iter_logical_constraints',
#  'iter_mip_starts',
#  'iter_multi_objective_exprs',
#  'iter_multi_objective_tuples',
#  'iter_progress_listeners',
#  'iter_pwl_constraints',
#  'iter_pwl_functions',
#  'iter_quadratic_constraints',
#  'iter_range_constraints',
#  'iter_semicontinuous_vars',
#  'iter_semiinteger_vars',
#  'iter_sos',
#  'iter_sos1',
#  'iter_sos2',
#  'iter_user_cut_constraints',
#  'iter_var_containers',
#  'iter_variables',
#  'iter_vartypes',
#  'job_solve_status',
#  'keep_ordering',
#  'kpi_by_name',
#  'kpi_value_by_name',
#  'kpis_as_dict',
#  'le_constraint',
#  'lfactory',
#  'linear_constraint',
#  'linear_constraint_basis_statuses',
#  'linear_expr',
#  'log_output',
#  'logger',
#  'logical_and',
#  'logical_not',
#  'logical_or',
#  'lp_line_length',
#  'lp_string',
#  'max',
#  'maximize',
#  'maximize_static_lex',
#  'min',
#  'minimize',
#  'minimize_static_lex',
#  'mip_starts',
#  'multi_objective_values',
#  'name',
#  'new_solution',
#  'not_equal_constraint',
#  'notify_expr_modified',
#  'notify_expr_replaced',
#  'notify_solve_failed',
#  'notify_solve_relaxed',
#  'notify_start_solve',
#  'number_of_binary_variables',
#  'number_of_constraints',
#  'number_of_continuous_variables',
#  'number_of_equivalence_constraints',
#  'number_of_errors',
#  'number_of_generated_variables',
#  'number_of_indicator_constraints',
#  'number_of_integer_variables',
#  'number_of_kpis',
#  'number_of_lazy_constraints',
#  'number_of_linear_constraints',
#  'number_of_mip_starts',
#  'number_of_multi_objective_exprs',
#  'number_of_nonzeros',
#  'number_of_progress_listeners',
#  'number_of_pwl_constraints',
#  'number_of_quadratic_constraints',
#  'number_of_range_constraints',
#  'number_of_semicontinuous_variables',
#  'number_of_semiinteger_variables',
#  'number_of_sos',
#  'number_of_sos1',
#  'number_of_sos2',
#  'number_of_user_constraints',
#  'number_of_user_cut_constraints',
#  'number_of_user_variables',
#  'number_of_variables',
#  'number_of_warnings',
#  'objective_coef',
#  'objective_expr',
#  'objective_sense',
#  'objective_value',
#  'origin_key',
#  'output_level',
#  'parameters',
#  'piecewise',
#  'piecewise_as_slopes',
#  'populate',
#  'populate_solution_pool',
#  'pprint',
#  'pprint_as_string',
#  'prepare_actual_context',
#  'prettyprint',
#  'print_information',
#  'print_solution',
#  'problem_type',
#  'provenance',
#  'quad_expr',
#  'quadratic_dual_slacks',
#  'quality_metrics',
#  'range_constraint',
#  'read_basis_file',
#  'read_mip_starts',
#  'read_priority_order_file',
#  'readable_str_len',
#  'reduced_costs',
#  'register_callback',
#  'remove',
#  'remove_benders_annotation',
#  'remove_constraint',
#  'remove_constraints',
#  'remove_kpi',
#  'remove_objective',
#  'remove_progress_listener',
#  'report',
#  'report_kpis',
#  'restore_numpy',
#  'restore_solution',
#  'resync_engine',
#  'round_solution',
#  'scal_prod',
#  'scal_prod_f',
#  'scal_prod_vars_all_different',
#  'semicontinuous_var',
#  'semicontinuous_var_dict',
#  'semicontinuous_var_list',
#  'semicontinuous_var_matrix',
#  'semicontinuous_vartype',
#  'semiinteger_var',
#  'semiinteger_var_dict',
#  'semiinteger_var_list',
#  'semiinteger_var_matrix',
#  'semiinteger_vartype',
#  'set_benders_annotation',
#  'set_checker',
#  'set_constraint_priority',
#  'set_hidden_parameter',
#  'set_lex_multi_objective',
#  'set_linear_constraint_name',
#  'set_log_output',
#  'set_log_output_as_stream',
#  'set_lp_start_basis',
#  'set_multi_objective',
#  'set_multi_objective_abstols',
#  'set_multi_objective_exprs',
#  'set_multi_objective_reltols',
#  'set_obj_origin',
#  'set_objective',
#  'set_objective_expr',
#  'set_objective_sense',
#  'set_quiet',
#  'set_time_limit',
#  'set_var_container',
#  'set_var_lb',
#  'set_var_name',
#  'set_var_ub',
#  'slack_values',
#  'solution',
#  'solve',
#  'solve_details',
#  'solve_status',
#  'solve_with_goals',
#  'solved_stopped_by_limit',
#  'solver_agent',
#  'solves_with',
#  'statistics',
#  'str_max_len',
#  'str_space',
#  'str_use_space',
#  'sum',
#  'sum_squares',
#  'sum_vars',
#  'sum_vars_all_different',
#  'sums',
#  'sumsq',
#  'supports_logical_constraints',
#  'supports_multi_objective',
#  'sync_cplex_engine',
#  'time_limit',
#  'time_limit_parameter',
#  'to_string',
#  'trace',
#  'unsupported_power_error',
#  'unsupported_relational_operator_error',
#  'var',
#  'var_basis_statuses',
#  'var_dict',
#  'var_hypercube',
#  'var_list',
#  'var_matrix',
#  'vector_compare',
#  'vector_compare_eq',
#  'vector_compare_ge',
#  'vector_compare_le',
#  'warning']

# %%
objective = model.get_objective_expr()
objective
# Out:
# docplex.mp.quad.QuadExpr(7.646iTrade_020002BJ9^2+18.679iTrade_020002BJ9*iTrade_026874DS3+16.169iTrade_020002BJ9*iTrade_15135BAW1+19.356iTrade_020002BJ9*iTrade_21871XAS8+9.954iTrade_020002BJ9*iTrade_444859BR2+19.187iTrade_020002BJ9*iTrade_444859BV3+19.260iTrade_020002BJ9*iTrade_444859BY7+18.691iTrade_020002BJ9*iTrade_444859CA8+17.365iTrade_020002BJ9*iTrade_540424AT5+17.313iTrade_020002BJ9*iTrade_56501RAN6+17.153iTrade_020002BJ9*iTrade_759351AP4+13.545iTrade_020002BJ9*iTrade_91324PEJ7+11.409iTrade_026874DS3^2+19.751iTrade_026874DS3*iTrade_15135BAW1+23.644iTrade_026874DS3*iTrade_21871XAS8+12.159iTrade_026874DS3*iTrade_444859BR2+23.438iTrade_026874DS3*iTrade_444859BV3+23.527iTrade_026874DS3*iTrade_444859BY7+22.832iTrade_026874DS3*iTrade_444859CA8+21.212iTrade_026874DS3*iTrade_540424AT5+21.148iTrade_026874DS3*iTrade_56501RAN6+20.954iTrade_026874DS3*iTrade_759351AP4+16.546iTrade_026874DS3*iTrade_91324PEJ7+8.962iTrade_081437AT2^2+8.826iTrade_081437AT2*iTrade_097023CJ2+21.337iTrade_081437AT2*iTrade_14448CBC7+12.928iTrade_081437AT2*iTrade_24422EWZ8+20.508iTrade_081437AT2*iTrade_24422EXP9+20.008iTrade_081437AT2*iTrade_36166NAK9+19.909iTrade_081437AT2*iTrade_438516CM6+11.450iTrade_081437AT2*iTrade_443201AC2+8.474iTrade_081437AT2*iTrade_45687VAB2+20.167iTrade_081437AT2*iTrade_539830CD9+16.230iTrade_081437AT2*iTrade_75513EAD3+16.613iTrade_081437AT2*iTrade_760759BA7+20.149iTrade_081437AT2*iTrade_760759BC3+2.173iTrade_097023CJ2^2+10.507iTrade_097023CJ2*iTrade_14448CBC7+6.366iTrade_097023CJ2*iTrade_24422EWZ8+10.099iTrade_097023CJ2*iTrade_24422EXP9+9.852iTrade_097023CJ2*iTrade_36166NAK9+9.803iTrade_097023CJ2*iTrade_438516CM6+5.638iTrade_097023CJ2*iTrade_443201AC2+4.173iTrade_097023CJ2*iTrade_45687VAB2+9.930iTrade_097023CJ2*iTrade_539830CD9+7.992iTrade_097023CJ2*iTrade_75513EAD3+8.180iTrade_097023CJ2*iTrade_760759BA7+9.922iTrade_097023CJ2*iTrade_760759BC3+49.883iTrade_13645RAD6^2+54.356iTrade_13645RAD6*iTrade_13645RBF0+58.936iTrade_13645RAD6*iTrade_314353AA1+174.274iTrade_13645RAD6*iTrade_655844CR7+24.142iTrade_13645RAD6*iTrade_655844CT3+78.394iTrade_13645RAD6*iTrade_907818FX1+14.808iTrade_13645RBF0^2+32.110iTrade_13645RBF0*iTrade_314353AA1+94.951iTrade_13645RBF0*iTrade_655844CR7+13.154iTrade_13645RBF0*iTrade_655844CT3+42.712iTrade_13645RBF0*iTrade_907818FX1+12.700iTrade_14448CBC7^2+15.389iTrade_14448CBC7*iTrade_24422EWZ8+24.413iTrade_14448CBC7*iTrade_24422EXP9+23.818iTrade_14448CBC7*iTrade_36166NAK9+23.699iTrade_14448CBC7*iTrade_438516CM6+13.630iTrade_14448CBC7*iTrade_443201AC2+10.088iTrade_14448CBC7*iTrade_45687VAB2+24.007iTrade_14448CBC7*iTrade_539830CD9+19.320iTrade_14448CBC7*iTrade_75513EAD3+19.776iTrade_14448CBC7*iTrade_760759BA7+23.985iTrade_14448CBC7*iTrade_760759BC3+8.548iTrade_15135BAW1^2+20.466iTrade_15135BAW1*iTrade_21871XAS8+10.525iTrade_15135BAW1*iTrade_444859BR2+20.288iTrade_15135BAW1*iTrade_444859BV3+20.366iTrade_15135BAW1*iTrade_444859BY7+19.764iTrade_15135BAW1*iTrade_444859CA8+18.361iTrade_15135BAW1*iTrade_540424AT5+18.306iTrade_15135BAW1*iTrade_56501RAN6+18.138iTrade_15135BAW1*iTrade_759351AP4+14.322iTrade_15135BAW1*iTrade_91324PEJ7+12.250iTrade_21871XAS8^2+12.599iTrade_21871XAS8*iTrade_444859BR2+24.287iTrade_21871XAS8*iTrade_444859BV3+24.379iTrade_21871XAS8*iTrade_444859BY7+23.659iTrade_21871XAS8*iTrade_444859CA8+21.980iTrade_21871XAS8*iTrade_540424AT5+21.914iTrade_21871XAS8*iTrade_56501RAN6+21.713iTrade_21871XAS8*iTrade_759351AP4+17.145iTrade_21871XAS8*iTrade_91324PEJ7+4.662iTrade_24422EWZ8^2+14.792iTrade_24422EWZ8*iTrade_24422EXP9+14.431iTrade_24422EWZ8*iTrade_36166NAK9+14.359iTrade_24422EWZ8*iTrade_438516CM6+8.258iTrade_24422EWZ8*iTrade_443201AC2+6.112iTrade_24422EWZ8*iTrade_45687VAB2+14.545iTrade_24422EWZ8*iTrade_539830CD9+11.706iTrade_24422EWZ8*iTrade_75513EAD3+11.982iTrade_24422EWZ8*iTrade_760759BA7+14.532iTrade_24422EWZ8*iTrade_760759BC3+11.733iTrade_24422EXP9^2+22.893iTrade_24422EXP9*iTrade_36166NAK9+22.779iTrade_24422EXP9*iTrade_438516CM6+13.100iTrade_24422EXP9*iTrade_443201AC2+9.696iTrade_24422EXP9*iTrade_45687VAB2 ...

# %% [markdown]
# To understand the objective function, you need to inspect manually the
# file `.lp`

# %% [markdown]
# ```
# 36fund_enriched.pmv_tgt_Investment_Grade_Credit_Capital_Goods^2
#  + 36fund_enriched.pmv_tgt_Investment_Grade_Credit_Insurance^2
#  + 36fund_enriched.pmv_tgt_Investment_Grade_Credit_Transporation^2
# ```

# %%
dir(objective)
# Out:
# ['__abstractmethods__',
#  '__add__',
#  '__array_priority__',
#  '__class__',
#  '__contains__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__div__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__iadd__',
#  '__idiv__',
#  '__imul__',
#  '__init__',
#  '__init_subclass__',
#  '__isub__',
#  '__iter__',
#  '__itruediv__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__mul__',
#  '__ne__',
#  '__neg__',
#  '__new__',
#  '__pow__',
#  '__radd__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__rmul__',
#  '__rsub__',
#  '__setattr__',
#  '__sizeof__',
#  '__slots__',
#  '__str__',
#  '__sub__',
#  '__subclasshook__',
#  '__truediv__',
#  '__weakref__',
#  '_abc_impl',
#  '_add_one_quad_term',
#  '_add_quad',
#  '_assign_scaled',
#  '_check_model_has_solution',
#  '_generate_quad_triplets',
#  '_get_quadratic_coefficient',
#  '_get_quadratic_coefficient_from_var_pair',
#  '_iter_sorted_quads',
#  '_linexpr',
#  '_model',
#  '_new_empty_subscribers',
#  '_new_term_dict',
#  '_num_to_stringio',
#  '_quad_variable_set',
#  '_quadterms',
#  '_raw_solution_value',
#  '_round_if_discrete',
#  '_scale',
#  '_set_quadratic_coefficient',
#  '_set_quadratic_coefficient_internal',
#  '_set_quadratic_coefficients',
#  '_subscribers',
#  '_subtract_quad',
#  '_transient',
#  '_unsupported_binary_operation',
#  'add',
#  'as_constant',
#  'clear',
#  'clear_subscribers',
#  'clone',
#  'clone_if_necessary',
#  'compute_separable_convexity',
#  'constant',
#  'contains_quad',
#  'contains_var',
#  'copy',
#  'divide',
#  'eq',
#  'equals',
#  'error',
#  'error_handler',
#  'fatal',
#  'float_precision',
#  'ge',
#  'get_constant',
#  'get_linear_factory',
#  'get_linear_part',
#  'get_quadratic_coefficient',
#  'grab_subscribers',
#  'has_quadratic_term',
#  'is_constant',
#  'is_discrete',
#  'is_in_model',
#  'is_in_use',
#  'is_normalized',
#  'is_quad_expr',
#  'is_separable',
#  'is_shared',
#  'is_used_by',
#  'is_zero',
#  'iter_opposite_ordered_quads',
#  'iter_quad_triplets',
#  'iter_quad_variables',
#  'iter_quad_vars',
#  'iter_quads',
#  'iter_sorted_quads',
#  'iter_subscribers',
#  'iter_terms',
#  'iter_variables',
#  'keep',
#  'le',
#  'lfactory',
#  'linear_part',
#  'logger',
#  'minus',
#  'model',
#  'multiply',
#  'name',
#  'nb_subscribers',
#  'negate',
#  'normalize',
#  'normalized',
#  'notify_expr_modified',
#  'notify_modified',
#  'notify_replaced',
#  'notify_subscribed',
#  'notify_unsubscribed',
#  'notify_used',
#  'number_of_quadratic_terms',
#  'number_of_variables',
#  'plus',
#  'qfactory',
#  'quotient',
#  'raw_solution_value',
#  'relaxed_copy',
#  'repr_str',
#  'resolve',
#  'rminus',
#  'rsubtract',
#  'rsv',
#  'set_constant',
#  'set_quadratic_coefficient',
#  'size',
#  'solution_value',
#  'square',
#  'subtract',
#  'sv',
#  'times',
#  'to_linear_expr',
#  'to_readable_string',
#  'to_string',
#  'to_stringio',
#  'warning',
#  'zero_expr']

# %% [markdown]
# ### Variables

# %%
variables_info = []
for var in model.iter_variables():
  var_info = {
    'name': var.name, 
    'type': 'binary' if var.is_binary() else
      'integer' if var.is_integer() else 
      'continuous'if var.is_continuous() else '',
    'lower_bound': var.lb,
    'upper_bound': var.ub
  }

  variables_info.append(var_info)

variables_info
# Out:
# [{'name': 'iTrade_020002BJ9',
#   'type': 'binary',
#   'lower_bound': 0,
#   'upper_bound': 1.0},
#  {'name': 'iTrade_026874DS3',
#   'type': 'binary',
#   'lower_bound': 0,
#   'upper_bound': 1.0},
#  {'name': 'iTrade_081437AT2',
#   'type': 'binary',
#   'lower_bound': 0,
#   'upper_bound': 1.0},
#  {'name': 'iTrade_097023CJ2',
#   'type': 'binary',
#   'lower_bound': 0,
#   'upper_bound': 1.0},
#  {'name': 'iTrade_13645RAD6',
#   'type': 'binary',
#   'lower_bound': 0,
#   'upper_bound': 1.0},
#  {'name': 'iTrade_13645RBF0',
#   'type': 'binary',
#   'lower_bound': 0,
#   'upper_bound': 1.0},
#  {'name': 'iTrade_14448CBC7',
#   'type': 'binary',
#   'lower_bound': 0,
#   'upper_bound': 1.0},
#  {'name': 'iTrade_15135BAW1',
#   'type': 'binary',
#   'lower_bound': 0,
#   'upper_bound': 1.0},
#  {'name': 'iTrade_21871XAS8',
#   'type': 'binary',
#   'lower_bound': 0,
#   'upper_bound': 1.0},
#  {'name': 'iTrade_24422EWZ8',
#   'type': 'binary',
#   'lower_bound': 0,
#   'upper_bound': 1.0},
#  {'name': 'iTrade_24422EXP9',
#   'type': 'binary',
#   'lower_bound': 0,
#   'upper_bound': 1.0},
#  {'name': 'iTrade_314353AA1',
#   'type': 'binary',
#   'lower_bound': 0,
#   'upper_bound': 1.0},
#  {'name': 'iTrade_36166NAK9',
#   'type': 'binary',
#   'lower_bound': 0,
#   'upper_bound': 1.0},
#  {'name': 'iTrade_438516CM6',
#   'type': 'binary',
#   'lower_bound': 0,
#   'upper_bound': 1.0},
#  {'name': 'iTrade_443201AC2',
#   'type': 'binary',
#   'lower_bound': 0,
#   'upper_bound': 1.0},
#  {'name': 'iTrade_444859BR2',
#   'type': 'binary',
#   'lower_bound': 0,
#   'upper_bound': 1.0},
#  {'name': 'iTrade_444859BV3',
#   'type': 'binary',
#   'lower_bound': 0,
#   'upper_bound': 1.0},
#  {'name': 'iTrade_444859BY7',
#   'type': 'binary',
#   'lower_bound': 0,
#   'upper_bound': 1.0},
#  {'name': 'iTrade_444859CA8',
#   'type': 'binary',
#   'lower_bound': 0,
#   'upper_bound': 1.0},
#  {'name': 'iTrade_45687VAB2',
#   'type': 'binary',
#   'lower_bound': 0,
#   'upper_bound': 1.0},
#  {'name': 'iTrade_539830CD9',
#   'type': 'binary',
#   'lower_bound': 0,
#   'upper_bound': 1.0},
#  {'name': 'iTrade_540424AT5',
#   'type': 'binary',
#   'lower_bound': 0,
#   'upper_bound': 1.0},
#  {'name': 'iTrade_56501RAN6',
#   'type': 'binary',
#   'lower_bound': 0,
#   'upper_bound': 1.0},
#  {'name': 'iTrade_655844CR7',
#   'type': 'binary',
#   'lower_bound': 0,
#   'upper_bound': 1.0},
#  {'name': 'iTrade_655844CT3',
#   'type': 'binary',
#   'lower_bound': 0,
#   'upper_bound': 1.0},
#  {'name': 'iTrade_75513EAD3',
#   'type': 'binary',
#   'lower_bound': 0,
#   'upper_bound': 1.0},
#  {'name': 'iTrade_759351AP4',
#   'type': 'binary',
#   'lower_bound': 0,
#   'upper_bound': 1.0},
#  {'name': 'iTrade_760759BA7',
#   'type': 'binary',
#   'lower_bound': 0,
#   'upper_bound': 1.0},
#  {'name': 'iTrade_760759BC3',
#   'type': 'binary',
#   'lower_bound': 0,
#   'upper_bound': 1.0},
#  {'name': 'iTrade_907818FX1',
#   'type': 'binary',
#   'lower_bound': 0,
#   'upper_bound': 1.0},
#  {'name': 'iTrade_91324PEJ7',
#   'type': 'binary',
#   'lower_bound': 0,
#   'upper_bound': 1.0},
#  {'name': None, 'type': 'binary', 'lower_bound': 0, 'upper_bound': 1}]

# %% [markdown]
# ### Constraints

# %%
constraints_info = []

for constraint in model.iter_constraints():
  const_info = {
    'name': constraint.name if constraint.name else 'unnamed',
    'type': str(type(constraint).__name__),
    'expression': str(constraint)
  }

  constraints_info.append(const_info)

constraints_info
# Out:
# [{'name': 'trade_num_upper_limit',
#   'type': 'LinearConstraint',
#   'expression': 'trade_num_upper_limit: iTrade_020002BJ9+iTrade_026874DS3+iTrade_081437AT2+iTrade_097023CJ2+iTrade_13645RAD6+iTrade_13645RBF0+iTrade_14448CBC7+iTrade_15135BAW1+iTrade_21871XAS8+iTrade_24422EWZ8+iTrade_24422EXP9+iTrade_314353AA1+iTrade_36166NAK9+iTrade_438516CM6+iTrade_443201AC2+iTrade_444859BR2+iTrade_444859BV3+iTrade_444859BY7+iTrade_444859CA8+iTrade_45687VAB2+iTrade_539830CD9+iTrade_540424AT5+iTrade_56501RAN6+iTrade_655844CR7+iTrade_655844CT3+iTrade_75513EAD3+iTrade_759351AP4+iTrade_760759BA7+iTrade_760759BC3+iTrade_907818FX1+iTrade_91324PEJ7 <= 500.0'},
#  {'name': 'limit_sodraw.filterLevel1_sodraw.filterLevel3_Investment_Grade_Credit_Capital_Goods_fund_enriched.pmv_min',
#   'type': 'LinearConstraint',
#   'expression': 'limit_sodraw.filterLevel1_sodraw.filterLevel3_Investment_Grade_Credit_Capital_Goods_fund_enriched.pmv_min: 0.499iTrade_081437AT2+0.246iTrade_097023CJ2+0.594iTrade_14448CBC7+0.360iTrade_24422EWZ8+0.571iTrade_24422EXP9+0.557iTrade_36166NAK9+0.554iTrade_438516CM6+0.319iTrade_443201AC2+0.236iTrade_45687VAB2+0.561iTrade_539830CD9+0.452iTrade_75513EAD3+0.462iTrade_760759BA7+0.561iTrade_760759BC3 >= 4.758736462913'},
#  {'name': 'limit_sodraw.filterLevel1_sodraw.filterLevel3_Investment_Grade_Credit_Capital_Goods_fund_enriched.pmv_max',
#   'type': 'LinearConstraint',
#   'expression': 'limit_sodraw.filterLevel1_sodraw.filterLevel3_Investment_Grade_Credit_Capital_Goods_fund_enriched.pmv_max: 0.499iTrade_081437AT2+0.246iTrade_097023CJ2+0.594iTrade_14448CBC7+0.360iTrade_24422EWZ8+0.571iTrade_24422EXP9+0.557iTrade_36166NAK9+0.554iTrade_438516CM6+0.319iTrade_443201AC2+0.236iTrade_45687VAB2+0.561iTrade_539830CD9+0.452iTrade_75513EAD3+0.462iTrade_760759BA7+0.561iTrade_760759BC3 <= 6.847872350911'},
#  {'name': 'limit_sodraw.filterLevel1_sodraw.filterLevel3_Investment_Grade_Credit_Capital_Goods_fund_enriched.dxsCtr_min',
#   'type': 'LinearConstraint',
#   'expression': 'limit_sodraw.filterLevel1_sodraw.filterLevel3_Investment_Grade_Credit_Capital_Goods_fund_enriched.dxsCtr_min: 233.033iTrade_081437AT2+310.154iTrade_097023CJ2+393.283iTrade_14448CBC7+81.610iTrade_24422EWZ8+281.943iTrade_24422EXP9+261.482iTrade_36166NAK9+236.651iTrade_438516CM6+141.545iTrade_443201AC2+140.650iTrade_45687VAB2+277.463iTrade_539830CD9+150.456iTrade_75513EAD3+269.290iTrade_760759BA7+327.570iTrade_760759BC3 >= 1780.68926045072'},
#  {'name': 'limit_sodraw.filterLevel1_sodraw.filterLevel3_Investment_Grade_Credit_Capital_Goods_fund_enriched.dxsCtr_max',
#   'type': 'LinearConstraint',
#   'expression': 'limit_sodraw.filterLevel1_sodraw.filterLevel3_Investment_Grade_Credit_Capital_Goods_fund_enriched.dxsCtr_max: 233.033iTrade_081437AT2+310.154iTrade_097023CJ2+393.283iTrade_14448CBC7+81.610iTrade_24422EWZ8+281.943iTrade_24422EXP9+261.482iTrade_36166NAK9+236.651iTrade_438516CM6+141.545iTrade_443201AC2+140.650iTrade_45687VAB2+277.463iTrade_539830CD9+150.456iTrade_75513EAD3+269.290iTrade_760759BA7+327.570iTrade_760759BC3 <= 3869.825148448374'},
#  {'name': 'limit_sodraw.filterLevel1_sodraw.filterLevel3_Investment_Grade_Credit_Insurance_fund_enriched.pmv_min',
#   'type': 'LinearConstraint',
#   'expression': 'limit_sodraw.filterLevel1_sodraw.filterLevel3_Investment_Grade_Credit_Insurance_fund_enriched.pmv_min: 0.461iTrade_020002BJ9+0.563iTrade_026874DS3+0.487iTrade_15135BAW1+0.583iTrade_21871XAS8+0.300iTrade_444859BR2+0.578iTrade_444859BV3+0.580iTrade_444859BY7+0.563iTrade_444859CA8+0.523iTrade_540424AT5+0.522iTrade_56501RAN6+0.517iTrade_759351AP4+0.408iTrade_91324PEJ7 >= 4.134392251914'},
#  {'name': 'limit_sodraw.filterLevel1_sodraw.filterLevel3_Investment_Grade_Credit_Insurance_fund_enriched.pmv_max',
#   'type': 'LinearConstraint',
#   'expression': 'limit_sodraw.filterLevel1_sodraw.filterLevel3_Investment_Grade_Credit_Insurance_fund_enriched.pmv_max: 0.461iTrade_020002BJ9+0.563iTrade_026874DS3+0.487iTrade_15135BAW1+0.583iTrade_21871XAS8+0.300iTrade_444859BR2+0.578iTrade_444859BV3+0.580iTrade_444859BY7+0.563iTrade_444859CA8+0.523iTrade_540424AT5+0.522iTrade_56501RAN6+0.517iTrade_759351AP4+0.408iTrade_91324PEJ7 <= 6.223528139912'},
#  {'name': 'limit_sodraw.filterLevel1_sodraw.filterLevel3_Investment_Grade_Credit_Insurance_fund_enriched.dxsCtr_min',
#   'type': 'LinearConstraint',
#   'expression': 'limit_sodraw.filterLevel1_sodraw.filterLevel3_Investment_Grade_Credit_Insurance_fund_enriched.dxsCtr_min: 205.580iTrade_020002BJ9+337.862iTrade_026874DS3+378.464iTrade_15135BAW1+472.068iTrade_21871XAS8+226.708iTrade_444859BR2+485.654iTrade_444859BV3+535.670iTrade_444859BY7+338.723iTrade_444859CA8+181.360iTrade_540424AT5+229.006iTrade_56501RAN6+209.560iTrade_759351AP4+152.828iTrade_91324PEJ7 >= 1991.42972820855'},
#  {'name': 'limit_sodraw.filterLevel1_sodraw.filterLevel3_Investment_Grade_Credit_Insurance_fund_enriched.dxsCtr_max',
#   'type': 'LinearConstraint',
#   'expression': 'limit_sodraw.filterLevel1_sodraw.filterLevel3_Investment_Grade_Credit_Insurance_fund_enriched.dxsCtr_max: 205.580iTrade_020002BJ9+337.862iTrade_026874DS3+378.464iTrade_15135BAW1+472.068iTrade_21871XAS8+226.708iTrade_444859BR2+485.654iTrade_444859BV3+535.670iTrade_444859BY7+338.723iTrade_444859CA8+181.360iTrade_540424AT5+229.006iTrade_56501RAN6+209.560iTrade_759351AP4+152.828iTrade_91324PEJ7 <= 4080.565616206205'},
#  {'name': 'limit_sodraw.filterLevel1_sodraw.filterLevel3_Investment_Grade_Credit_Transportation_fund_enriched.pmv_min',
#   'type': 'LinearConstraint',
#   'expression': 'limit_sodraw.filterLevel1_sodraw.filterLevel3_Investment_Grade_Credit_Transportation_fund_enriched.pmv_min: 1.177iTrade_13645RAD6+0.641iTrade_13645RBF0+0.695iTrade_314353AA1+2.056iTrade_655844CR7+0.285iTrade_655844CT3+0.925iTrade_907818FX1 >= 0.240014083139'},
#  {'name': 'limit_sodraw.filterLevel1_sodraw.filterLevel3_Investment_Grade_Credit_Transportation_fund_enriched.pmv_max',
#   'type': 'LinearConstraint',
#   'expression': 'limit_sodraw.filterLevel1_sodraw.filterLevel3_Investment_Grade_Credit_Transportation_fund_enriched.pmv_max: 1.177iTrade_13645RAD6+0.641iTrade_13645RBF0+0.695iTrade_314353AA1+2.056iTrade_655844CR7+0.285iTrade_655844CT3+0.925iTrade_907818FX1 <= 2.329149971137'},
#  {'name': 'limit_sodraw.filterLevel1_sodraw.filterLevel3_Investment_Grade_Credit_Transportation_fund_enriched.dxsCtr_min',
#   'type': 'LinearConstraint',
#   'expression': 'limit_sodraw.filterLevel1_sodraw.filterLevel3_Investment_Grade_Credit_Transportation_fund_enriched.dxsCtr_min: 490.408iTrade_13645RAD6+242.413iTrade_13645RBF0+218.306iTrade_314353AA1+554.590iTrade_655844CR7+156.488iTrade_655844CT3+309.123iTrade_907818FX1 >= -479.881210498972'},
#  {'name': 'limit_sodraw.filterLevel1_sodraw.filterLevel3_Investment_Grade_Credit_Transportation_fund_enriched.dxsCtr_max',
#   'type': 'LinearConstraint',
#   'expression': 'limit_sodraw.filterLevel1_sodraw.filterLevel3_Investment_Grade_Credit_Transportation_fund_enriched.dxsCtr_max: 490.408iTrade_13645RAD6+242.413iTrade_13645RBF0+218.306iTrade_314353AA1+554.590iTrade_655844CR7+156.488iTrade_655844CT3+309.123iTrade_907818FX1 <= 1609.254677498683'},
#  {'name': 'low_cnstr_cash',
#   'type': 'LinearConstraint',
#   'expression': 'low_cnstr_cash: 0.461iTrade_020002BJ9+0.563iTrade_026874DS3+0.499iTrade_081437AT2+0.246iTrade_097023CJ2+1.177iTrade_13645RAD6+0.641iTrade_13645RBF0+0.594iTrade_14448CBC7+0.487iTrade_15135BAW1+0.583iTrade_21871XAS8+0.360iTrade_24422EWZ8+0.571iTrade_24422EXP9+0.695iTrade_314353AA1+0.557iTrade_36166NAK9+0.554iTrade_438516CM6+0.319iTrade_443201AC2+0.300iTrade_444859BR2+0.578iTrade_444859BV3+0.580iTrade_444859BY7+0.563iTrade_444859CA8+0.236iTrade_45687VAB2+0.561iTrade_539830CD9+0.523iTrade_540424AT5+0.522iTrade_56501RAN6+2.056iTrade_655844CR7+0.285iTrade_655844CT3+0.452iTrade_75513EAD3+0.517iTrade_759351AP4+0.462iTrade_760759BA7+0.561iTrade_760759BC3+0.925iTrade_907818FX1+0.408iTrade_91324PEJ7 >= 2.600974180557'},
#  {'name': 'cnstr_cash',
#   'type': 'LinearConstraint',
#   'expression': 'cnstr_cash: 0.461iTrade_020002BJ9+0.563iTrade_026874DS3+0.499iTrade_081437AT2+0.246iTrade_097023CJ2+1.177iTrade_13645RAD6+0.641iTrade_13645RBF0+0.594iTrade_14448CBC7+0.487iTrade_15135BAW1+0.583iTrade_21871XAS8+0.360iTrade_24422EWZ8+0.571iTrade_24422EXP9+0.695iTrade_314353AA1+0.557iTrade_36166NAK9+0.554iTrade_438516CM6+0.319iTrade_443201AC2+0.300iTrade_444859BR2+0.578iTrade_444859BV3+0.580iTrade_444859BY7+0.563iTrade_444859CA8+0.236iTrade_45687VAB2+0.561iTrade_539830CD9+0.523iTrade_540424AT5+0.522iTrade_56501RAN6+2.056iTrade_655844CR7+0.285iTrade_655844CT3+0.452iTrade_75513EAD3+0.517iTrade_759351AP4+0.462iTrade_760759BA7+0.561iTrade_760759BC3+0.925iTrade_907818FX1+0.408iTrade_91324PEJ7 <= 10.435233760548'}]

# %% [markdown]
# ### Solution

# %%
# sol_file = "./data/1/full/docplex-orig.sol"
# solve_sol = SolveSolution.from_file(sol_file, model)
# solve_sol

# %%
dir(solve_sol[0])
# Out:
# ['NO_OBJECTIVE_VALUE',
#  '__as_df__',
#  '__class__',
#  '__contains__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__setitem__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_accept_value',
#  '_as_dict',
#  '_basis_statuses',
#  '_blended_objective_by_priority',
#  '_checker',
#  '_cuts',
#  '_dual_values',
#  '_export',
#  '_export_as_string',
#  '_get_all_values',
#  '_get_status',
#  '_get_values',
#  '_get_var_by_name',
#  '_get_var_value',
#  '_has_basis',
#  '_infeasibilities',
#  '_is_discrete_value',
#  '_keep_zeros',
#  '_model',
#  '_name',
#  '_new_printer',
#  '_objective',
#  '_problem_objective_expr',
#  '_reduced_costs',
#  '_resolve_attribute_index_map',
#  '_resolve_attribute_list',
#  '_resolve_var',
#  '_sensitivity',
#  '_set_solve_status',
#  '_set_var_key_value',
#  '_set_var_value',
#  '_set_var_value_internal',
#  '_slack_values',
#  '_solve_details',
#  '_solve_status',
#  '_solved_by',
#  '_static_export',
#  '_store_var_value_map',
#  '_typecheck_var_key_value',
#  '_var_value_map',
#  'add_var_value',
#  'as_df',
#  'as_dict',
#  'as_index_dict',
#  'as_mip_start',
#  'as_name_dict',
#  'blended_objective_values',
#  'check_as_mip_start',
#  'clear',
#  'contains',
#  'display',
#  'display_attributes',
#  'ensure_basis_statuses',
#  'ensure_cuts',
#  'ensure_dual_values',
#  'ensure_reduced_costs',
#  'ensure_slack_values',
#  'equals',
#  'export',
#  'export_as_json_string',
#  'export_as_mst',
#  'export_as_mst_string',
#  'export_as_sol',
#  'export_as_sol_string',
#  'find_invalid_domain_variables',
#  'find_unsatisfied_constraints',
#  'from_file',
#  'get_blended_objective_value_by_priority',
#  'get_cuts',
#  'get_dual_values',
#  'get_infeasibility',
#  'get_linearct_basis_statuses',
#  'get_num_cuts',
#  'get_objective_value',
#  'get_reduced_costs',
#  'get_sensitivity',
#  'get_slacks',
#  'get_status',
#  'get_value',
#  'get_value_df',
#  'get_value_dict',
#  'get_value_list',
#  'get_values',
#  'get_var_basis_statuses',
#  'get_var_value',
#  'has_basis',
#  'has_objective',
#  'is_empty',
#  'is_feasible_solution',
#  'is_valid_solution',
#  'iter_var_values',
#  'iter_variables',
#  'kpi_value_by_name',
#  'make_engine_solution',
#  'model',
#  'multi_objective_values',
#  'name',
#  'number_of_var_diffs',
#  'number_of_var_values',
#  'objective_value',
#  'print_mst',
#  'problem_name',
#  'restore',
#  'set_name',
#  'set_objective_value',
#  'set_var_key_value',
#  'size',
#  'slack_value',
#  'solve_details',
#  'solve_status',
#  'solved_by',
#  'store_attribute_lists',
#  'store_infeasibilities',
#  'to_string',
#  'to_stringio',
#  'update']
